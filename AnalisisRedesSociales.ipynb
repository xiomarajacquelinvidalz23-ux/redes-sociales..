# %% [markdown]
# <a href="https://colab.research.google.com/github/xiomarajacquelinvidalz23-ux/redes-sociales../blob/main/AnalisisRedesSociales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORTAMOS LIBRERIAS

# %% [markdown]
# PROYECTO ELABORADO POR :
# JAQUELIN LOPEZ TOLENTINO
# XIOMARA JACQUELIN VIDAL ZEPAHUA

# %%
pip install googletrans==4.0.0-rc1

# %%
import kagglehub
import os
import pandas as pd # Necesario para el paso final

# %% [markdown]
# #IMPORTAMOS CONJUNTO DE DATOS DIRECTO DE KAGLE
# [Conjunto de datos de redes sociales](https://www.kaggle.com/datasets/jocelyndumlao/social-media-and-consumer-behavior-2025)

# %%
# Download latest version

path = kagglehub.dataset_download("jocelyndumlao/social-media-and-consumer-behavior-2025")
print("Path to dataset files:", path)
# Asume que 'path' es la ruta principal de descarga
# Ejemplo: path = '/content/kaggle/jocelyndumlao/social-media-and-consumer-behavior-2025/1'

contenido_inicial = os.listdir(path)
print("Contenido inicial (debería ser la subcarpeta):", contenido_inicial)

# Asumimos que el primer elemento de la lista es la subcarpeta
if contenido_inicial:
    nombre_subcarpeta = contenido_inicial[0]

    # Construir la ruta a la subcarpeta
    nueva_ruta = os.path.join(path, nombre_subcarpeta)
    print(f"\nSe ha detectado una subcarpeta: **{nombre_subcarpeta}**")

# Listar el contenido de la subcarpeta
archivos_finales = os.listdir(nueva_ruta)
print("\nArchivos dentro de la subcarpeta:")
for archivo in archivos_finales:
    print(archivo)


nombre_archivo_csv='Impacto dos Algoritmos das Redes Sociais no Comportamento de Consumo em Rondon do Pará.csv'
# Unir la ruta de la subcarpeta con el nombre del archivo CSV
ruta_completa_csv = os.path.join(nueva_ruta, nombre_archivo_csv)

# Cargar el archivo en un DataFrame de Pandas
try:
    df_redesSociales = pd.read_csv(ruta_completa_csv)
    print("\n¡Carga exitosa del DataFrame!")
except FileNotFoundError:
    print(f"\nERROR: No se encontró el archivo '{nombre_archivo_csv}' en la ruta: {nueva_ruta}. Verifica el nombre.")
# Out:
# Using Colab cache for faster access to the 'social-media-and-consumer-behavior-2025' dataset.
# Path to dataset files: /kaggle/input/social-media-and-consumer-behavior-2025
# Contenido inicial (debería ser la subcarpeta): ['Dataset on the Impact of Social Media Algorithms o']
#
# Se ha detectado una subcarpeta: **Dataset on the Impact of Social Media Algorithms o**
#
# Archivos dentro de la subcarpeta:
# Impacto dos Algoritmos das Redes Sociais no Comportamento de Consumo em Rondon do Pará.csv
#
# ¡Carga exitosa del DataFrame!

# %% [markdown]
# # PREPROCESAMOS LA INFORMACIÓN

# %%
df_redesSociales
# Out:
#             Carimbo de data/hora Caracterização Sociodemográficas.   2- Sexo:  \
# 0    2025/10/14 4:26:09 PM GMT-3                   de 18 a 29 anos   Feminino
# 1    2025/10/14 4:28:54 PM GMT-3                   de 18 a 29 anos   Feminino
# 2    2025/10/14 4:32:40 PM GMT-3                   de 18 a 29 anos   Feminino
# 3    2025/10/14 4:33:54 PM GMT-3                   de 18 a 29 anos   Feminino
# 4    2025/10/14 4:35:07 PM GMT-3                   de 30 a 39 anos   Feminino
# ..                           ...                               ...        ...
# 89   2025/10/23 3:42:52 PM GMT-3                   de 18 a 29 anos   Feminino
# 90  2025/10/24 12:56:40 PM GMT-3                   de 18 a 29 anos   Feminino
# 91   2025/10/27 3:23:46 PM GMT-3                   de 18 a 29 anos   Feminino
# 92   2025/10/27 3:28:38 PM GMT-3                   de 30 a 39 anos  Masculino
# 93   2025/11/07 8:20:04 AM GMT-3                   de 18 a 29 anos  Masculino
#
# ...

# %%
#Quitamos los indices del DF
df_redesSociales=df_redesSociales.reset_index();

# %% [markdown]
# ### Renombrando las columnas del DataFrame
#
# Para facilitar el análisis y la lectura de los datos, vamos a renombrar las columnas del DataFrame `df_redesSociales` con nombres más concisos y descriptivos.

# %%
column_rename_mapping = {
    'index': 'ID_Respuesta',
    'Carimbo de data/hora': 'Fecha_Hora',
    'Caracterização Sociodemográficas.': 'Rango_Edad',
    '2- Sexo:': 'Sexo',
    '3- Escolaridade': 'Nivel_Escolaridad',
    '4-  Ocupação principal:': 'Ocupacion_Principal',
    '5- Renda mensal pessoal aproximada:': 'Ingreso_Mensual_Aproximado',
    'Uso de Redes Sociais': 'Redes_Sociales_Usadas',
    '7- Tempo médio diário de uso das redes sociais': 'Tiempo_Diario_Redes_Sociales',
    '8- Com que frequência você visualiza anúncios nas redes sociais?': 'Frecuencia_Anuncios_Redes',
    '9- Você já realizou alguma compra após ver um anúncio nas redes sociais?': 'Compra_Tras_Anuncio',
    'Influência dos Algoritmos e Anúncios Personalizados': 'Influencia_Algoritmos_Anuncios',
    '11- Percebo que os anúncios são adaptados ao meu comportamento de navegação.': 'Anuncios_Adaptados_Comportamiento',
    '12- Os algoritmos me fazem ver produtos que despertam meu interesse de compra.': 'Algoritmos_motivan_Compra',
    '13- Sinto que os algoritmos \"conhecem\" meus gostos e preferências.': 'Algoritmos_Preferencias',
    '14- O conteúdo das redes sociais influencia minhas decisões de compra?': 'Influencia_Contenido_Redes',
    '15- Os anúncios personalizados aumentam minha probabilidade de comprar produtos.': 'Anuncios_Personalizados_Aumentan_Compra',
    'Influência de Influenciadores Digitais': 'Influencia_Influencers',
    '17- As recomendações de influenciadores afetam minhas decisões de compra.': 'Influencers_motivan_Compra',
    '18- Confio mais em produtos recomendados por influenciadores do que em propagandas tradicionais.': 'Influencers_vs_Propaganda',
    '19- Já comprei produtos com base em recomendações de influenciadores nas redes sociais.': 'Compra_Por_Recomendacion_influencers',
    'Comportamento de Consumo Online': 'Comportamiento_Consumo_Online',
    '21- O preço é o principal fator que me leva a optar por compras online.': 'Precio_Principal_Fator_Compras',
    '22- A praticidade das compras online me faz comprar com mais frequência.': 'Aumento_Frecuencia_Compras_Online',
    '23- Considero as avaliações e comentários de outros consumidores antes de comprar.': 'comentarios_Antes_Compra',
    '24- Já deixei de comprar em loja física porque encontrei melhor oferta nas redes sociais.': 'NO_compra_Fisica_Por_Redes_Sociales',
    'Comércio Local e Percepções Finais': 'Percepcion_comercio_local',
    '26- Gostaria que as lojas locais utilizassem mais as redes sociais para divulgar seus produtos.': 'divulgación_en_Redes_Sociales',
    '27- Se as lojas locais anunciassem de forma personalizada, eu compraria delas.': 'Compra_a_los negocios_Anunciados',
    '28- As redes sociais podem ser usadas de forma positiva para fortalecer o comércio local.': 'Redes_Sociales_Fortalecen_Comercio_Local'
}

# Renombrar las columnas
df_redesSociales = df_redesSociales.rename(columns=column_rename_mapping)

# Opcional: Eliminar las columnas que eran solo encabezados si no se consideran útiles como tal.
# Por ahora, las mantendré renombradas para no perder información.
# Si quieres eliminarlas, puedes usar:
# df_redesSociales = df_redesSociales.drop(columns=[
#     'Seccion_Influencia_Algoritmos_Anuncios',
#     'Seccion_Influencia_Influenciadores_Digitales',
#     'Seccion_Comportamiento_Consumo_Online',
#     'Seccion_Comercio_Local_Percepciones_Finais'
# ])

# Mostrar las nuevas columnas para verificar
print("Nuevas columnas del DataFrame:\n")
for col in df_redesSociales.columns:
    print(col)

# Mostrar las primeras filas con las nuevas columnas
print("\nPrimeras 5 filas del DataFrame con columnas renombradas:\n")
display(df_redesSociales.head())
# Out:
# Nuevas columnas del DataFrame:
#
# ID_Respuesta
# Fecha_Hora
# Rango_Edad
# Sexo
# Nivel_Escolaridad
# Ocupacion_Principal
# Ingreso_Mensual_Aproximado
# Redes_Sociales_Usadas
# Tiempo_Diario_Redes_Sociales
# Frecuencia_Anuncios_Redes
# Compra_Tras_Anuncio
# Influencia_Algoritmos_Anuncios
# Anuncios_Adaptados_Comportamiento
# Algoritmos_motivan_Compra
# Algoritmos_Preferencias
# Influencia_Contenido_Redes
# Anuncios_Personalizados_Aumentan_Compra
# Influencia_Influencers
# Influencers_motivan_Compra
# Influencers_vs_Propaganda
# Compra_Por_Recomendacion_influencers
# Comportamiento_Consumo_Online
# Precio_Principal_Fator_Compras
# Aumento_Frecuencia_Compras_Online
# comentarios_Antes_Compra
# NO_compra_Fisica_Por_Redes_Sociales
# Percepcion_comercio_local
# divulgación_en_Redes_Sociales
# Compra_a_los negocios_Anunciados
# Redes_Sociales_Fortalecen_Comercio_Local
#
# Primeras 5 filas del DataFrame con columnas renombradas:
# ...

# %% [markdown]
# Luego, puedes usar el siguiente código para traducir un texto:

# %%
from googletrans import Translator

def translate_text_pt_es(text):
    translator = Translator()
    try:
        translated = translator.translate(text, src='pt', dest='es')
        return translated.text
    except Exception as e:
        # Fallback for keys that might not be Portuguese or cause translation errors
        return text # Return original if translation fails

# Existing mapping from original/Portuguese to new Spanish names
# This is assumed to be defined from a previous step, but re-defining for clarity
column_rename_mapping = {
    'index': 'ID_Respuesta',
    'Carimbo de data/hora': 'Fecha_Hora',
    'Caracterização Sociodemográficas.': 'Rango_Edad',
    '2- Sexo:': 'Sexo',
    '3- Escolaridade': 'Nivel_Escolaridad',
    '4-  Ocupação principal:': 'Ocupacion_Principal',
    '5- Renda mensal pessoal aproximada:': 'Ingreso_Mensual_Aproximado',
    'Uso de Redes Sociais': 'Redes_Sociales_Usadas',
    '7- Tempo médio diário de uso das redes sociais': 'Tiempo_Diario_Redes_Sociales',
    '8- Com que frequência você visualiza anúncios nas redes sociais?': 'Frecuencia_Anuncios_Redes',
    '9- Você já realizou alguma compra após ver um anúncio nas redes sociais?': 'Compra_Tras_Anuncio',
    'Influência dos Algoritmos e Anúncios Personalizados': 'Influencia_Algoritmos_Anuncios',
    '11- Percebo que os anúncios são adaptados ao meu comportamento de navegação.': 'Anuncios_Adaptados_Comportamiento',
    '12- Os algoritmos me fazem ver produtos que despertam meu interesse de compra.': 'Algoritmos_motivan_Compra',
    '13- Sinto que os algoritmos \"conhecem\" meus gostos e preferências.': 'Algoritmos_Preferencias',
    '14- O conteúdo das redes sociais influencia minhas decisões de compra?': 'Influencia_Contenido_Redes',
    '15- Os anúncios personalizados aumentam minha probabilidade de comprar produtos.': 'Anuncios_Personalizados_Aumentan_Compra',
    'Influência de Influenciadores Digitais': 'Influencia_Influencers',
    '17- As recomendações de influenciadores afetam minhas decisões de compra.': 'Influencers_motivan_Compra',
    '18- Confio mais em produtos recomendados por influenciadores do que em propagandas tradicionais.': 'Influencers_vs_Propaganda',
    '19- Já comprei produtos com base em recomendações de influenciadores nas redes sociais.': 'Compra_Por_Recomendacion_influencers',
    'Comportamento de Consumo Online': 'Comportamiento_Consumo_Online',
    '21- O preço é o principal fator que me leva a optar por compras online.': 'Precio_Principal_Fator_Compras',
    '22- A praticidade das compras online me faz comprar com mais frequência.': 'Aumento_Frecuencia_Compras_Online',
    '23- Considero as avaliações e comentários de outros consumidores antes de comprar.': 'comentarios_Antes_Compra',
    '24- Já deixei de comprar em loja física porque encontrei melhor oferta nas redes sociais.': 'NO_compra_Fisica_Por_Redes_Sociales',
    'Comércio Local e Percepções Finais': 'Percepcion_comercio_local',
    '26- Gostaria que as lojas locais utilizassem mais as redes sociais para divulgar seus produtos.': 'divulgación_en_Redes_Sociales',
    '27- Se as lojas locais anunciassem de forma personalizada, eu compraria delas.': 'Compra_a_los negocios_Anunciados',
    '28- As redes sociais podem ser usadas de forma positiva para fortalecer o comércio local.': 'Redes_Sociales_Fortalecen_Comercio_Local'
}

# Crear el nuevo diccionario con las claves traducidas al español
original_to_new_translated_map = {}

for original_key_pt, new_value_es in column_rename_mapping.items():
    # Handle 'index' specifically as it's not a Portuguese column name,
    # and its 'translated' form should align with 'ID_Respuesta'
    if original_key_pt == 'index':
        translated_key_es = 'ID de Respuesta'
    else:
        translated_key_es = translate_text_pt_es(original_key_pt)
    original_to_new_translated_map[translated_key_es] = new_value_es

print("Diccionario de nombres originales (traducidos a español) a nuevos nombres:")
for original_translated, new_name in original_to_new_translated_map.items():
    print(f"{original_translated}: {new_name}")
# Out:
# Diccionario de nombres originales (traducidos a español) a nuevos nombres:
# ID de Respuesta: ID_Respuesta
# Marca de tiempo: Fecha_Hora
# Caracterización sociodemográfica.: Rango_Edad
# 2- Sexo:: Sexo
# 3- Educación: Nivel_Escolaridad
# 4- Ocupación principal:: Ocupacion_Principal
# 5- Ingresos personales mensuales aproximados:: Ingreso_Mensual_Aproximado
# Uso de las redes sociales: Redes_Sociales_Usadas
# 7- Tiempo medio diario dedicado al uso de las redes sociales: Tiempo_Diario_Redes_Sociales
# 8- ¿Con qué frecuencia ves anuncios en las redes sociales?: Frecuencia_Anuncios_Redes
# 9- ¿Alguna vez has realizado una compra después de ver un anuncio en las redes sociales?: Compra_Tras_Anuncio
# Influencia de los algoritmos y los anuncios personalizados: Influencia_Algoritmos_Anuncios
# 11- Noto que los anuncios se adaptan a mi comportamiento de navegación.: Anuncios_Adaptados_Comportamiento
# ...

# %%
df_redesSociales.columns
# Out:
# Index(['ID_Respuesta', 'Fecha_Hora', 'Rango_Edad', 'Sexo', 'Nivel_Escolaridad',
#        'Ocupacion_Principal', 'Ingreso_Mensual_Aproximado',
#        'Redes_Sociales_Usadas', 'Tiempo_Diario_Redes_Sociales',
#        'Frecuencia_Anuncios_Redes', 'Compra_Tras_Anuncio',
#        'Influencia_Algoritmos_Anuncios', 'Anuncios_Adaptados_Comportamiento',
#        'Algoritmos_motivan_Compra', 'Algoritmos_Preferencias',
#        'Influencia_Contenido_Redes', 'Anuncios_Personalizados_Aumentan_Compra',
#        'Influencia_Influencers', 'Influencers_motivan_Compra',
#        'Influencers_vs_Propaganda', 'Compra_Por_Recomendacion_influencers',
#        'Comportamiento_Consumo_Online', 'Precio_Principal_Fator_Compras',
#        'Aumento_Frecuencia_Compras_Online', 'comentarios_Antes_Compra',
#        'NO_compra_Fisica_Por_Redes_Sociales', 'Percepcion_comercio_local',
#        'divulgación_en_Redes_Sociales', 'Compra_a_los negocios_Anunciados',
#        'Redes_Sociales_Fortalecen_Comercio_Local'],
# ...

# %%
from googletrans import Translator

translator = Translator()

# Función para traducir texto de portugués a español
def translate_text_pt_es(text):
    try:
        if pd.isnull(text):  # Si el valor es NaN, lo dejamos igual
            return text
        translated = translator.translate(text, src='pt', dest='es')
        return translated.text
    except:
        return text  # Si falla, devuelve el original

# Ejemplo: traducir la columna 'Nivel_Escolaridad'
df_redesSociales['Nivel_Escolaridad_ES'] = df_redesSociales['Nivel_Escolaridad'].apply(translate_text_pt_es)

# Revisar resultados
print(df_redesSociales[['Nivel_Escolaridad','Nivel_Escolaridad_ES']].head())
# Out:
#   Nivel_Escolaridad Nivel_Escolaridad_ES
# 0   Ensino Superior   Educación superior
# 1      Ensino Médio   Escuela secundaria
# 2      Ensino Médio   Escuela secundaria
# 3   Ensino Superior   Educación superior
# 4   Ensino Superior   Educación superior

# %%
df_redesSociales
# Out:
#     ID_Respuesta                    Fecha_Hora       Rango_Edad       Sexo  \
# 0              0   2025/10/14 4:26:09 PM GMT-3  de 18 a 29 anos   Feminino
# 1              1   2025/10/14 4:28:54 PM GMT-3  de 18 a 29 anos   Feminino
# 2              2   2025/10/14 4:32:40 PM GMT-3  de 18 a 29 anos   Feminino
# 3              3   2025/10/14 4:33:54 PM GMT-3  de 18 a 29 anos   Feminino
# 4              4   2025/10/14 4:35:07 PM GMT-3  de 30 a 39 anos   Feminino
# ..           ...                           ...              ...        ...
# 89            89   2025/10/23 3:42:52 PM GMT-3  de 18 a 29 anos   Feminino
# 90            90  2025/10/24 12:56:40 PM GMT-3  de 18 a 29 anos   Feminino
# 91            91   2025/10/27 3:23:46 PM GMT-3  de 18 a 29 anos   Feminino
# 92            92   2025/10/27 3:28:38 PM GMT-3  de 30 a 39 anos  Masculino
# 93            93   2025/11/07 8:20:04 AM GMT-3  de 18 a 29 anos  Masculino
#
# ...

# %%
from googletrans import Translator
translator = Translator()

# Función para traducir texto de portugués a español
def translate_text_pt_es(text):
    try:
        if pd.isnull(text):  # Si el valor es NaN, lo dejamos igual
            return text
        translated = translator.translate(text, src='pt', dest='es')
        return translated.text
    except:
        return text  # Si falla, devuelve el original

# 1. Traducir Rango_Edad
df_redesSociales['Rango_Edad_ES'] = df_redesSociales['Rango_Edad'].apply(translate_text_pt_es)
# 2. Traducir Sexo
df_redesSociales['Sexo_ES'] = df_redesSociales['Sexo'].apply(translate_text_pt_es)

# 3. Traducir Nivel_Escolaridad
df_redesSociales['Nivel_Escolaridad_ES'] = df_redesSociales['Nivel_Escolaridad'].apply(translate_text_pt_es)

# 4. Traducir Ocupacion_Principal
df_redesSociales['Ocupacion_Principal_ES'] = df_redesSociales['Ocupacion_Principal'].apply(translate_text_pt_es)

# 5. Traducir Ingreso_Mensual_Aproximado
df_redesSociales['Ingreso_Mensual_Aproximado_ES'] = df_redesSociales['Ingreso_Mensual_Aproximado'].apply(translate_text_pt_es)

# 6. Traducir Redes_Sociales_Usadas
df_redesSociales['Redes_Sociales_Usadas_ES'] = df_redesSociales['Redes_Sociales_Usadas'].apply(translate_text_pt_es)

# 7. Traducir Tiempo_Diario_Redes_Sociales
df_redesSociales['Tiempo_Diario_Redes_Sociales_ES'] = df_redesSociales['Tiempo_Diario_Redes_Sociales'].apply(translate_text_pt_es)

# 8. Traducir Frecuencia_Anuncios_Redes
df_redesSociales['Frecuencia_Anuncios_Redes_ES'] = df_redesSociales['Frecuencia_Anuncios_Redes'].apply(translate_text_pt_es)

# 9. Traducir Compra_Tras_Anuncio
df_redesSociales['Compra_Tras_Anuncio_ES'] = df_redesSociales['Compra_Tras_Anuncio'].apply(translate_text_pt_es)

# 10. Traducir Influencia_Algoritmos_Anuncios
df_redesSociales['Influencia_Algoritmos_Anuncios_ES'] = df_redesSociales['Influencia_Algoritmos_Anuncios'].apply(translate_text_pt_es)

# 11. Traducir Anuncios_Adaptados_Comportamiento
df_redesSociales['Anuncios_Adaptados_Comportamiento_ES'] = df_redesSociales['Anuncios_Adaptados_Comportamiento'].apply(translate_text_pt_es)

# 12. Traducir Algoritmos_motivan_Compra
df_redesSociales['Algoritmos_motivan_Compra_ES'] = df_redesSociales['Algoritmos_motivan_Compra'].apply(translate_text_pt_es)

# 13. Traducir Algoritmos_Preferencias
df_redesSociales['Algoritmos_Preferencias_ES'] = df_redesSociales['Algoritmos_Preferencias'].apply(translate_text_pt_es)

# 14. Traducir Influencia_Contenido_Redes
df_redesSociales['Influencia_Contenido_Redes_ES'] = df_redesSociales['Influencia_Contenido_Redes'].apply(translate_text_pt_es)

# 15. Traducir Anuncios_Personalizados_Aumentan_Compra
df_redesSociales['Anuncios_Personalizados_Aumentan_Compra_ES'] = df_redesSociales['Anuncios_Personalizados_Aumentan_Compra'].apply(translate_text_pt_es)

# 16. Traducir Influencia_Influencers
df_redesSociales['Influencia_Influencers_ES'] = df_redesSociales['Influencia_Influencers'].apply(translate_text_pt_es)

# 17. Traducir Influencers_motivan_Compra
df_redesSociales['Influencers_motivan_Compra_ES'] = df_redesSociales['Influencers_motivan_Compra'].apply(translate_text_pt_es)

# 18. Traducir Influencers_vs_Propaganda
df_redesSociales['Influencers_vs_Propaganda_ES'] = df_redesSociales['Influencers_vs_Propaganda'].apply(translate_text_pt_es)

# 19. Traducir Compra_Por_Recomendacion_influencers
df_redesSociales['Compra_Por_Recomendacion_influencers_ES'] = df_redesSociales['Compra_Por_Recomendacion_influencers'].apply(translate_text_pt_es)

# 20. Traducir Comportamiento_Consumo_Online
df_redesSociales['Comportamiento_Consumo_Online_ES'] = df_redesSociales['Comportamiento_Consumo_Online'].apply(translate_text_pt_es)

# 21. Traducir Precio_Principal_Fator_Compras
df_redesSociales['Precio_Principal_Fator_Compras_ES'] = df_redesSociales['Precio_Principal_Fator_Compras'].apply(translate_text_pt_es)

# 22. Traducir Aumento_Frecuencia_Compras_Online
df_redesSociales['Aumento_Frecuencia_Compras_Online_ES'] = df_redesSociales['Aumento_Frecuencia_Compras_Online'].apply(translate_text_pt_es)

# 23. Traducir comentarios_Antes_Compra
df_redesSociales['comentarios_Antes_Compra_ES'] = df_redesSociales['comentarios_Antes_Compra'].apply(translate_text_pt_es)

# 24. Traducir NO_compra_Fisica_Por_Redes_Sociales
df_redesSociales['NO_compra_Fisica_Por_Redes_Sociales_ES'] = df_redesSociales['NO_compra_Fisica_Por_Redes_Sociales'].apply(translate_text_pt_es)

# 25. Traducir Percepcion_comercio_local
df_redesSociales['Percepcion_comercio_local_ES'] = df_redesSociales['Percepcion_comercio_local'].apply(translate_text_pt_es)

# 26. Traducir divulgación_en_Redes_Sociales
df_redesSociales['divulgación_en_Redes_Sociales_ES'] = df_redesSociales['divulgación_en_Redes_Sociales'].apply(translate_text_pt_es)

# 27. Traducir Compra_a_los negocios_Anunciados
df_redesSociales['Compra_a_los_negocios_Anunciados_ES'] = df_redesSociales['Compra_a_los negocios_Anunciados'].apply(translate_text_pt_es)

# 28. Traducir Redes_Sociales_Fortalecen_Comercio_Local
df_redesSociales['Redes_Sociales_Fortalecen_Comercio_Local_ES'] = df_redesSociales['Redes_Sociales_Fortalecen_Comercio_Local'].apply(translate_text_pt_es)

# ============================
# VERIFICACIÓN
# ============================
print("\nPrimeras filas con columnas traducidas:\n")
display(df_redesSociales.head())
# Out:
# Primeras filas con columnas traducidas:
#    ID_Respuesta                   Fecha_Hora       Rango_Edad      Sexo  \
# 0             0  2025/10/14 4:26:09 PM GMT-3  de 18 a 29 anos  Feminino
# 1             1  2025/10/14 4:28:54 PM GMT-3  de 18 a 29 anos  Feminino
# 2             2  2025/10/14 4:32:40 PM GMT-3  de 18 a 29 anos  Feminino
# 3             3  2025/10/14 4:33:54 PM GMT-3  de 18 a 29 anos  Feminino
# 4             4  2025/10/14 4:35:07 PM GMT-3  de 30 a 39 anos  Feminino
#
#   Nivel_Escolaridad      Ocupacion_Principal Ingreso_Mensual_Aproximado  \
# 0   Ensino Superior                Estudante       Até 1 salário mínimo
# 1      Ensino Médio  Trabalhador assalariado          De 1 a 2 salários
# 2      Ensino Médio             Desempregado       Até 1 salário mínimo
# 3   Ensino Superior                Estudante       Até 1 salário mínimo
# 4   Ensino Superior  Trabalhador assalariado          De 1 a 2 salários
#
# ...

# %%
df_redesSociales
# Out:
#     ID_Respuesta                    Fecha_Hora       Rango_Edad       Sexo  \
# 0              0   2025/10/14 4:26:09 PM GMT-3  de 18 a 29 anos   Feminino
# 1              1   2025/10/14 4:28:54 PM GMT-3  de 18 a 29 anos   Feminino
# 2              2   2025/10/14 4:32:40 PM GMT-3  de 18 a 29 anos   Feminino
# 3              3   2025/10/14 4:33:54 PM GMT-3  de 18 a 29 anos   Feminino
# 4              4   2025/10/14 4:35:07 PM GMT-3  de 30 a 39 anos   Feminino
# ..           ...                           ...              ...        ...
# 89            89   2025/10/23 3:42:52 PM GMT-3  de 18 a 29 anos   Feminino
# 90            90  2025/10/24 12:56:40 PM GMT-3  de 18 a 29 anos   Feminino
# 91            91   2025/10/27 3:23:46 PM GMT-3  de 18 a 29 anos   Feminino
# 92            92   2025/10/27 3:28:38 PM GMT-3  de 30 a 39 anos  Masculino
# 93            93   2025/11/07 8:20:04 AM GMT-3  de 18 a 29 anos  Masculino
#
# ...

# %% [markdown]
# # 1.NO. DE PERSONAS POR INGRESO (NO SALARIOS)

# %%
# Contar número de personas por ingreso mensual aproximado
conteo_ingresos = df_redesSociales['Ingreso_Mensual_Aproximado_ES'].value_counts()

print("\nNúmero de personas por ingreso mensual aproximado:\n")
print(conteo_ingresos)

# %%
import matplotlib.pyplot as plt

# Contar número de personas por ingreso
conteo_ingresos = df_redesSociales['Ingreso_Mensual_Aproximado_ES'].value_counts()

# Ordenar por índice (opcional, si tus rangos están definidos como categorías)
conteo_ingresos = conteo_ingresos.sort_index()

# Crear gráfica de barras
plt.figure(figsize=(10,6))
conteo_ingresos.plot(kind='bar', color='skyblue', edgecolor='black')

# Títulos y etiquetas
plt.title("Número de personas por rango de ingreso mensual aproximado", fontsize=14)
plt.xlabel("Rango de ingreso mensual", fontsize=12)
plt.ylabel("Número de personas", fontsize=12)

# Rotar etiquetas para mejor lectura
plt.xticks(rotation=45, ha='right')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
import unicodedata
import pandas as pd

# Función para normalizar texto (minúsculas, quitar acentos, espacios)
def normalizar_texto(s):
    if pd.isnull(s):
        return s
    s = str(s).casefold()  # minúsculas
    s = ''.join(c for c in unicodedata.normalize('NFKD', s) if not unicodedata.combining(c))  # quitar acentos
    s = s.strip()
    return s

# Normalizar la columna de ocupación
df_redesSociales['Ocupacion_Normalizada'] = df_redesSociales['Ocupacion_Principal_ES'].apply(normalizar_texto)

# Diccionario de equivalencias para estudiantes
mapa = {
    'estudante': 'Estudiante',
    'estudiante': 'Estudiante',
    'alumno': 'Estudiante',
    'universitario': 'Estudiante'
}

# Reemplazar valores normalizados por categorías limpias
df_redesSociales['Ocupacion_Normalizada'] = df_redesSociales['Ocupacion_Normalizada'].replace(mapa)

# Contar estudiantes
num_estudiantes = (df_redesSociales['Ocupacion_Normalizada'] == 'Estudiante').sum()
print(f"Número de personas que son estudiantes: {num_estudiantes}")

# %% [markdown]
# #2. NO. DE PERSONAS QUE SON ESTUDIANTES

# %%
import matplotlib.pyplot as plt

# Contar las ocupaciones
ocupaciones = df_redesSociales['Ocupacion_Normalizada'].value_counts()

# Crear gráfica de pastel
plt.figure(figsize=(8,8))
plt.pie(
    ocupaciones,
    labels=ocupaciones.index,
    autopct='%1.1f%%',   # porcentaje con un decimal
    startangle=90,       # empezar desde arriba
    colors=plt.cm.Paired.colors  # paleta de colores
)

plt.title("Distribución de ocupaciones", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. RANGO DE EDAD EN EL QUE COMPRAN MAS

# %%
import pandas as pd

# Filtrar solo las personas que compraron
compradores = df_redesSociales[df_redesSociales['Compra_Tras_Anuncio_ES'] == 'Sí']

# Contar cuántos compradores hay por rango de edad
conteo_por_edad = compradores['Rango_Edad_ES'].value_counts().reset_index()
conteo_por_edad.columns = ['Rango_Edad', 'Num_Compradores']

print("\nNúmero de compradores por rango de edad:\n")
print(conteo_por_edad)

# Identificar el rango con más compras
rango_top = conteo_por_edad.loc[conteo_por_edad['Num_Compradores'].idxmax()]
print(f"\nEl rango de edad que compra más es: {rango_top['Rango_Edad']} con {rango_top['Num_Compradores']} personas.")

# %%
import matplotlib.pyplot as plt

# Lista de colores (puedes personalizarla)
colores = ['skyblue', 'salmon', 'mediumseagreen', 'gold', 'orchid', 'tomato', 'lightcoral']

plt.figure(figsize=(8,6))
plt.barh(
    conteo_por_edad['Rango_Edad'],
    conteo_por_edad['Num_Compradores'],
    color=colores[:len(conteo_por_edad)],  # asigna un color distinto a cada barra
    edgecolor='black'
)

plt.title("Compradores por rango de edad (barras horizontales)", fontsize=14)
plt.xlabel("Número de compradores", fontsize=12)
plt.ylabel("Rango de edad", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.RED SOCIAL MAS POPULAR

# %%
print(df_redesSociales["Redes_Sociales_Usadas"].head(20))

# %%
df_redesSociales

# %%
# Conteo de todas las redes sociales usadas
conteo_redes = df_redesSociales['Redes_Sociales_Usadas'].value_counts()

print("\nNúmero de personas por redes sociales usadas:\n")
print(conteo_redes)

# %%
import pandas as pd

# 1. Convertir todo a string
df_redesSociales["Redes_Sociales_Usadas"] = df_redesSociales["Redes_Sociales_Usadas"].astype(str)

# 2. Limpiar caracteres raros y separar por ";"
df_redesSociales["Redes_Sociales_Usadas"] = df_redesSociales["Redes_Sociales_Usadas"].apply(
    lambda x: [s.strip().lower() for s in x.replace("[","").replace("]","").replace("'","").split(";") if s.strip() != ""]
)

# 3. Explosión de listas para separar cada red social en filas
redes_exploded = df_redesSociales.explode("Redes_Sociales_Usadas")

# 4. Conteo individual de redes sociales
conteo_redes = redes_exploded["Redes_Sociales_Usadas"].value_counts()

print("\nNúmero de personas por redes sociales usadas:\n")
print(conteo_redes)
